# %%
import requests
import json

username = {}
datos_github = requests.get("https://api.github.com/users/MatiC-hub")

# %%
datos_github.json
# Out:
# <bound method Response.json of <Response [200]>>

# %%
datos_github.content
# Out:
# b'{"login":"MatiC-hub","id":230004317,"node_id":"U_kgDODbWWXQ","avatar_url":"https://avatars.githubusercontent.com/u/230004317?v=4","gravatar_id":"","url":"https://api.github.com/users/MatiC-hub","html_url":"https://github.com/MatiC-hub","followers_url":"https://api.github.com/users/MatiC-hub/followers","following_url":"https://api.github.com/users/MatiC-hub/following{/other_user}","gists_url":"https://api.github.com/users/MatiC-hub/gists{/gist_id}","starred_url":"https://api.github.com/users/MatiC-hub/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/MatiC-hub/subscriptions","organizations_url":"https://api.github.com/users/MatiC-hub/orgs","repos_url":"https://api.github.com/users/MatiC-hub/repos","events_url":"https://api.github.com/users/MatiC-hub/events{/privacy}","received_events_url":"https://api.github.com/users/MatiC-hub/received_events","type":"User","user_view_type":"public","site_admin":false,"name":null,"company":null,"blog":"","location":null,"email":null,"hireable":null,"bio":null,"twitter_username":null,"public_repos":2,"public_gists":0,"followers":0,"following":0,"created_at":"2025-09-02T17:06:57Z","updated_at":"2025-10-06T15:58:21Z"}'

# %%
respuesta = datos_github.json()
respuesta
# Out:
# {'login': 'MatiC-hub',
#  'id': 230004317,
#  'node_id': 'U_kgDODbWWXQ',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/230004317?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/MatiC-hub',
#  'html_url': 'https://github.com/MatiC-hub',
#  'followers_url': 'https://api.github.com/users/MatiC-hub/followers',
#  'following_url': 'https://api.github.com/users/MatiC-hub/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/MatiC-hub/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/MatiC-hub/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/MatiC-hub/subscriptions',
#  'organizations_url': 'https://api.github.com/users/MatiC-hub/orgs',
#  'repos_url': 'https://api.github.com/users/MatiC-hub/repos',
#  'events_url': 'https://api.github.com/users/MatiC-hub/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/MatiC-hub/received_events',
#  'type': 'User',
#  'user_view_type': 'public',
#  'site_admin': False,
#  'name': None,
#  'company': None,
#  'blog': '',
#  'location': None,
#  'email': None,
#  'hireable': None,
#  'bio': None,
#  'twitter_username': None,
#  'public_repos': 2,
#  'public_gists': 0,
#  'followers': 0,
#  'following': 0,
#  'created_at': '2025-09-02T17:06:57Z',
#  'updated_at': '2025-10-06T15:58:21Z'}

# %%
## API STAR WARS
import requests
personaje = input("Escribe el nombre de un personaje de Star Wars")
response = requests.get(f"https://swapi.py4e.com/api/people/?search={personaje}")
data = response.json()

for resultado in data["results"]:
    print(f"Nombre: {resultado['name']}")
# Out:
# Nombre: Luke Skywalker
# Nombre: Luminara Unduli

# %% [markdown]
# ## 4. Obtener datos energéticos usando la API de Red Eléctrica.
# La empresa para la que trabajamos tiene una base de datos con información sobre el número de personas censadas en las distintas Comunidades Autónomas españolas desde 1998 hasta 2022. Nuestro objetivo será enriquecer esos datos añadiendo información sobre la generación de energía renovable y no renovable en España, utilizando la API de REData, que ofrece datos actualizados sobre el mercado energético.
#
# 👉 Puedes consultar la documentación de la API en este enlace: https://www.ree.es/es/apidatos

# %%
import requests
import pandas as pd
from datetime import datetime

# %%
# Extracción de Datos a Nivel Nacional:
# Extraer datos de generación de energía renovable y no renovable a nivel nacional 
# desde el 1 de enero de 2011 hasta el 31 de diciembre de 2022. La información debe ser recopilada a nivel mensual.

url_electrica = (f"https://apidatos.ree.es/es/datos/generacion/estructura-generacion")
response = requests.get(url_electrica, params={"start_date": "2011-01-01T00:00", "end_date": "2022-12-31T23:59", "time_trunc": "month"})
response.status_code
# Out:
# 500

# %%
import requests

url = "https://apidatos.ree.es/es/datos/generacion/estructura-generacion"
params = {
    "start_date": "2022-01-01T00:00:00+01:00",
    "end_date": "2022-12-31T23:59:59+01:00",
    "time_trunc": "month"
}

data_total = []

# Bucle de años
for year in range(2011, 2023):  # 2023 no incluido, por eso llega hasta 2022
    start_date = f"{year}-01-01T00:00:00+01:00"
    end_date = f"{year}-12-31T23:59:59+01:00"

response = requests.get(url, params=params)
print(response.status_code)
print(response.url)  # para ver la URL completa
print(response.text[:500])  # ver un fragmento del contenido
print(f"Año {year}: status {response.status_code}")
# Out:
# 200
# https://apidatos.ree.es/es/datos/generacion/estructura-generacion?start_date=2022-01-01T00%3A00%3A00%2B01%3A00&end_date=2022-12-31T23%3A59%3A59%2B01%3A00&time_trunc=month
# {"data":{"type":"Generaci\u00f3n por tecnolog\u00eda","id":"gen1","attributes":{"title":"Generaci\u00f3n por tecnolog\u00eda","last-update":"2022-12-12T12:48:47.000+01:00","description":null},"meta":{"cache-control":{"cache":"HIT","expireAt":"2025-12-08T10:39:18"}}},"included":[{"type":"Hidr\u00e1ulica","id":"10288","groupId":"1","attributes":{"title":"Hidr\u00e1ulica","description":null,"color":"#0090d1","icon":null,"type":"Renovable","magnitude":null,"composite":false,"last-update":"2022-12-12
# Año 2022: status 200

# %%
data_total = response.json()

data_total

# %%
type(data_total)
# Out:
# dict

# %%
print(type(data_total))
print(len(data_total))
print(data_total)
# Out:
# <class 'dict'>
# 2
# {'data': {'type': 'Generación por tecnología', 'id': 'gen1', 'attributes': {'title': 'Generación por tecnología', 'last-update': '2022-12-12T12:48:47.000+01:00', 'description': None}, 'meta': {'cache-control': {'cache': 'HIT', 'expireAt': '2025-12-08T10:39:18'}}}, 'included': [{'type': 'Hidráulica', 'id': '10288', 'groupId': '1', 'attributes': {'title': 'Hidráulica', 'description': None, 'color': '#0090d1', 'icon': None, 'type': 'Renovable', 'magnitude': None, 'composite': False, 'last-update': '2022-12-12T12:48:38.000+01:00', 'values': [{'value': 2085857.451, 'percentage': 0.0865979014431461, 'datetime': '2022-01-01T00:00:00.000+01:00'}, {'value': 1174970.17, 'percentage': 0.05639231065537004, 'datetime': '2022-02-01T00:00:00.000+01:00'}, {'value': 1775478.144, 'percentage': 0.07892461852124848, 'datetime': '2022-03-01T00:00:00.000+01:00'}, {'value': 1802751.588, 'percentage': 0.08409999181045708, 'datetime': '2022-04-01T00:00:00.000+02:00'}, {'value': 1923714.557, 'percentage': 0.08841221262000502, 'datetime': '2022-05-01T00:00:00.000+02:00'}, {'value': 1192915.008, 'percentage': 0.051898346939567054, 'datetime': '2022-06-01T00:00:00.000+02:00'}, {'value': 1045015.928, 'percentage': 0.03987332754831628, 'datetime': '2022-07-01T00:00:00.000+02:00'}, {'value': 973565.249, 'percentage': 0.0390261951767793, 'datetime': '2022-08-01T00:00:00.000+02:00'}, {'value': 1154833.141, 'percentage': 0.04943333542177474, 'datetime': '2022-09-01T00:00:00.000+02:00'}, {'value': 719585.021, 'percentage': 0.033358888784469784, 'datetime': '2022-10-01T00:00:00.000+02:00'}, {'value': 1311831.73, 'percentage': 0.061993014441665543, 'datetime': '2022-11-01T00:00:00.000+01:00'}, {'value': 2750595.903, 'percentage': 0.12649085509598357, 'datetime': '2022-12-01T00:00:00.000+01:00'}]}}, {'type': 'Nuclear', 'id': '1446', 'groupId': '1', 'attributes': {'title': 'Nuclear', 'description': None, 'color': '#464394', 'icon': None, 'type': 'No-Renovable', 'magnitude': None, 'composite': False, 'last-update': '2023-11-28T14:44:18.000+01:00', 'values': [{'value': 5048424.951, 'percentage': 0.20959390400347053, 'datetime': '2022-01-01T00:00:00.000+01:00'}, {'value': 4771058.269, 'percentage': 0.22898538782505437, 'datetime': '2022-02-01T00:00:00.000+01:00'}, {'value': 4766690.052, 'percentage': 0.21189176292283893, 'datetime': '2022-03-01T00:00:00.000+01:00'}, {'value': 4414715.447, 'percentage': 0.2059504678346168, 'datetime': '2022-04-01T00:00:00.000+02:00'}, {'value': 4066355.361, 'percentage': 0.18688608112727886, 'datetime': '2022-05-01T00:00:00.000+02:00'}, {'value': 4459458.308, 'percentage': 0.19401090008846525, 'datetime': '2022-06-01T00:00:00.000+02:00'}, {'value': 5073367.597, 'percentage': 0.19357795661100707, 'datetime': '2022-07-01T00:00:00.000+02:00'}, {'value': 5122046.93, 'percentage': 0.20532162934135628, 'datetime': '2022-08-01T00:00:00.000+02:00'}, {'value': 4847367.123, 'percentage': 0.20749449976491643, 'datetime': '2022-09-01T00:00:00.000+02:00'}, {'value': 4021338.375, 'percentage': 0.18642325187636924, 'datetime': '2022-10-01T00:00:00.000+02:00'}, {'value': 4182092.888, 'percentage': 0.19763246983069296, 'datetime': '2022-11-01T00:00:00.000+01:00'}, {'value': 5161189.944, 'percentage': 0.23734614329110035, 'datetime': '2022-12-01T00:00:00.000+01:00'}]}}, {'type': 'Carbón', 'id': '10289', 'groupId': '1', 'attributes': {'title': 'Carbón', 'description': None, 'color': '#993300', 'icon': None, 'type': 'No-Renovable', 'magnitude': None, 'composite': False, 'last-update': '2022-02-08T09:13:13.000+01:00', 'values': [{'value': 709963.219, 'percentage': 0.029475324326571517, 'datetime': '2022-01-01T00:00:00.000+01:00'}, {'value': 568629.528, 'percentage': 0.027291189010179243, 'datetime': '2022-02-01T00:00:00.000+01:00'}, {'value': 705226.125, 'percentage': 0.03134913435850399, 'datetime': '2022-03-01T00:00:00.000+01:00'}, {'value': 691004.601, 'percentage': 0.03223598951287578, 'datetime': '2022-04-01T00:00:00.000+02:00'}, {'value': 527154.558,  ...

# %%
df = pd.DataFrame(data_total)

print(type(data_total))
print(len(data_total))
print(data_total[0])

# %%
import requests
import pandas as pd
from time import sleep  # para no saturar la API

# URL base
url = "https://apidatos.ree.es/es/datos/generacion/estructura-generacion"

# Lista para guardar todas las filas
data_total = []

# Rango de años
for year in range(2011, 2023):  # hasta 2022 incluido
    print(f"📅 Descargando datos del año {year}...")

    params = {
        "start_date": f"{year}-01-01T00:00:00+01:00",
        "end_date": f"{year}-12-31T23:59:59+01:00",
        "time_trunc": "month"
    }

    response = requests.get(url, params=params)

    # Comprobamos si la API responde bien
    if response.status_code == 200:
        json_data = response.json()

        # A veces puede no haber datos o estar vacío
        if "included" in json_data and json_data["included"]:
            for tech in json_data["included"]:
                nombre = tech["attributes"]["title"]
                valores = tech["attributes"]["values"]

                for v in valores:
                    fila = {
                        "año": year,
                        "tecnologia": nombre,
                        "fecha": v["datetime"],
                        "valor_MWh": v["value"],
                        "porcentaje": v["percentage"]
                    }
                    data_total.append(fila)
        else:
            print(f"⚠️ No hay datos para el año {year}")

    else:
        print(f"❌ Error {response.status_code} en el año {year}")

    # Pequeña pausa para no saturar el servidor
    sleep(0.5)

# Convertimos todo a DataFrame
df = pd.DataFrame(data_total)

# Mostramos el resultado
print(f"\n✅ Datos recopilados: {df.shape[0]} filas")
print(df.head())
# Out:
# 📅 Descargando datos del año 2011...
# 📅 Descargando datos del año 2012...
# 📅 Descargando datos del año 2013...
# 📅 Descargando datos del año 2014...
# 📅 Descargando datos del año 2015...
# 📅 Descargando datos del año 2016...
# 📅 Descargando datos del año 2017...
# 📅 Descargando datos del año 2018...
# 📅 Descargando datos del año 2019...
# 📅 Descargando datos del año 2020...
# 📅 Descargando datos del año 2021...
# 📅 Descargando datos del año 2022...
#
# ✅ Datos recopilados: 2343 filas
#     año  tecnologia                          fecha    valor_MWh  porcentaje
# 0  2011  Hidráulica  2011-01-01T00:00:00.000+01:00  5119512.380    0.199763
# 1  2011  Hidráulica  2011-02-01T00:00:00.000+01:00  2998051.279    0.130541
# 2  2011  Hidráulica  2011-03-01T00:00:00.000+01:00  3910363.276    0.157418
# 3  2011  Hidráulica  2011-04-01T00:00:00.000+02:00  3537937.995    0.164678
# 4  2011  Hidráulica  2011-05-01T00:00:00.000+02:00  2797500.027    0.128564

# %%
import requests
from time import sleep

diccionario_año = {"tipo_energia": [], "tipo_generacion": [], "fecha": [], "valor": [], "año": []}

for año in range(2011, 2023): 
    url_nacional = (
        f"https://apidatos.ree.es/es/datos/generacion/estructura-generacion"
        f"?start_date={año}-01-01T00:00:00+01:00"
        f"&end_date={año}-12-31T23:59:59+01:00"
        f"&time_trunc=month"
    )

    datos_año = requests.get(url_nacional)

    if datos_año.status_code != 200:
        print(f"❌ Error {datos_año.status_code} al descargar el año {año}")
        continue

    json_año = datos_año.json()

    if "included" not in json_año or not json_año["included"]:
        print(f"⚠️ No hay datos para {año}")
        continue

    for elemento in json_año["included"]:
        for dato in elemento["attributes"]["values"]:
            diccionario_año["tipo_energia"].append(elemento["attributes"]["title"])
            diccionario_año["tipo_generacion"].append(elemento["attributes"].get("type", "Desconocido"))
            diccionario_año["valor"].append(dato["value"])
            diccionario_año["fecha"].append(dato["datetime"])
            diccionario_año["año"].append(año)

    print(f"✅ Datos del año {año} procesados correctamente")
    sleep(0.5)
# Out:
# ❌ Error 500 al descargar el año 2011
# ❌ Error 500 al descargar el año 2012
# ❌ Error 500 al descargar el año 2013
# ❌ Error 500 al descargar el año 2014
# ❌ Error 500 al descargar el año 2015
# ❌ Error 500 al descargar el año 2016
# ❌ Error 500 al descargar el año 2017
# ❌ Error 500 al descargar el año 2018
# ❌ Error 500 al descargar el año 2019
# ❌ Error 500 al descargar el año 2020
# ❌ Error 500 al descargar el año 2021
# ❌ Error 500 al descargar el año 2022

# %%
import requests
from time import sleep
from datetime import datetime, timedelta

diccionario = {"tipo_energia": [], "tipo_generacion": [], "fecha": [], "valor": [], "año": []}

url_base = "https://apidatos.ree.es/es/datos/generacion/estructura-generacion"

for año in range(2011, 2023):
    for mes in range(1, 13):
        # Fecha de inicio y fin del mes
        inicio = datetime(año, mes, 1)
        if mes == 12:
            fin = datetime(año + 1, 1, 1) - timedelta(seconds=1)
        else:
            fin = datetime(año, mes + 1, 1) - timedelta(seconds=1)

        start_date = inicio.strftime("%Y-%m-%dT00:00:00+01:00")
        end_date = fin.strftime("%Y-%m-%dT23:59:59+01:00")

        params = {
            "start_date": start_date,
            "end_date": end_date,
            "time_trunc": "month"
        }

        response = requests.get(url_base, params=params)

        if response.status_code == 200:
            json_data = response.json()

            if "included" not in json_data or not json_data["included"]:
                print(f"⚠️ Sin datos {año}-{mes:02d}")
                continue

            for elemento in json_data["included"]:
                for dato in elemento["attributes"]["values"]:
                    diccionario["tipo_energia"].append(elemento["attributes"]["title"])
                    diccionario["tipo_generacion"].append(elemento["attributes"].get("type", "Desconocido"))
                    diccionario["valor"].append(dato["value"])
                    diccionario["fecha"].append(dato["datetime"])
                    diccionario["año"].append(año)

            print(f"✅ {año}-{mes:02d} descargado correctamente")

        else:
            print(f"❌ Error {response.status_code} en {año}-{mes:02d}")

        # Pequeña pausa para no saturar la API
        sleep(0.3)
# Out:
# ✅ 2011-01 descargado correctamente
# ✅ 2011-02 descargado correctamente
# ✅ 2011-03 descargado correctamente
# ✅ 2011-04 descargado correctamente
# ✅ 2011-05 descargado correctamente
# ✅ 2011-06 descargado correctamente
# ✅ 2011-07 descargado correctamente
# ✅ 2011-08 descargado correctamente
# ✅ 2011-09 descargado correctamente
# ✅ 2011-10 descargado correctamente
# ✅ 2011-11 descargado correctamente
# ✅ 2011-12 descargado correctamente
# ✅ 2012-01 descargado correctamente
# ✅ 2012-02 descargado correctamente
# ✅ 2012-03 descargado correctamente
# ✅ 2012-04 descargado correctamente
# ✅ 2012-05 descargado correctamente
# ✅ 2012-06 descargado correctamente
# ✅ 2012-07 descargado correctamente
# ✅ 2012-08 descargado correctamente
# ✅ 2012-09 descargado correctamente
# ✅ 2012-10 descargado correctamente
# ✅ 2012-11 descargado correctamente
# ✅ 2012-12 descargado correctamente
# ✅ 2013-01 descargado correctamente
# ✅ 2013-02 descargado correctamente
# ✅ 2013-03 descargado correctamente
# ✅ 2013-04 descargado correctamente
# ✅ 2013-05 descargado correctamente
# ✅ 2013-06 descargado correctamente
# ✅ 2013-07 descargado correctamente
# ✅ 2013-08 descargado correctamente
# ✅ 2013-09 descargado correctamente
# ✅ 2013-10 descargado correctamente
# ✅ 2013-11 descargado correctamente
# ✅ 2013-12 descargado correctamente
# ✅ 2014-01 descargado correctamente
# ✅ 2014-02 descargado correctamente
# ✅ 2014-03 descargado correctamente
# ✅ 2014-04 descargado correctamente
# ✅ 2014-05 descargado correctamente
# ✅ 2014-06 descargado correctamente
# ✅ 2014-07 descargado correctamente
# ✅ 2014-08 descargado correctamente
# ✅ 2014-09 descargado correctamente
# ✅ 2014-10 descargado correctamente
# ✅ 2014-11 descargado correctamente
# ✅ 2014-12 descargado correctamente
# ✅ 2015-01 descargado correctamente
# ✅ 2015-02 descargado correctamente
# ✅ 2015-03 descargado correctamente
# ✅ 2015-04 descargado correctamente
# ✅ 2015-05 descargado correctamente
# ✅ 2015-06 descargado correctamente
# ✅ 2015-07 descargado correctamente
# ✅ 2015-08 descargado correctamente
# ✅ 2015-09 descargado correctamente
# ✅ 2015-10 descargado correctamente
# ✅ 2015-11 descargado correctamente
# ✅ 2015-12 descargado correctamente
# ✅ 2016-01 descargado correctamente
# ✅ 2016-02 descargado correctamente
# ✅ 2016-03 descargado correctamente
# ✅ 2016-04 descargado correctamente
# ✅ 2016-05 descargado correctamente
# ✅ 2016-06 descargado correctamente
# ✅ 2016-07 descargado correctamente
# ✅ 2016-08 descargado correctamente
# ✅ 2016-09 descargado correctamente
# ✅ 2016-10 descargado correctamente
# ✅ 2016-11 descargado correctamente
# ✅ 2016-12 descargado correctamente
# ✅ 2017-01 descargado correctamente
# ✅ 2017-02 descargado correctamente
# ✅ 2017-03 descargado correctamente
# ✅ 2017-04 descargado correctamente
# ✅ 2017-05 descargado correctamente
# ✅ 2017-06 descargado correctamente
# ✅ 2017-07 descargado correctamente
# ✅ 2017-08 descargado correctamente
# ✅ 2017-09 descargado correctamente
# ✅ 2017-10 descargado correctamente
# ✅ 2017-11 descargado correctamente
# ✅ 2017-12 descargado correctamente
# ✅ 2018-01 descargado correctamente
# ✅ 2018-02 descargado correctamente
# ✅ 2018-03 descargado correctamente
# ✅ 2018-04 descargado correctamente
# ✅ 2018-05 descargado correctamente
# ✅ 2018-06 descargado correctamente
# ✅ 2018-07 descargado correctamente
# ✅ 2018-08 descargado correctamente
# ✅ 2018-09 descargado correctamente
# ✅ 2018-10 descargado correctamente
# ✅ 2018-11 descargado correctamente
# ✅ 2018-12 descargado correctamente
# ✅ 2019-01 descargado correctamente
# ✅ 2019-02 descargado correctamente
# ✅ 2019-03 descargado correctamente
# ✅ 2019-04 descargado correctamente
# ✅ 2019-05 descargado correctamente
# ✅ 2019-06 descargado correctamente
# ✅ 2019-07 descargado correctamente
# ✅ 2019-08 descargado correctamente
# ✅ 2019-09 descargado correctamente
# ✅ 2019-10 descargado correctamente
# ✅ 2019-11 descargado correctamente
# ✅ 2019-12 descargado correctamente
# ✅ 2020-01 descargado correctamente
# ✅ 2020-02 descargado correctamente
# ✅ 2020-03 descargado correctamente
# ✅ 2020-04 descargado correctamente
# ✅ 2020-05 descargado correctamente
# ✅ 2020-06 descargado correctamente
# ✅ 2020-07 descargado correctamente
# ✅ 2020-08 descargado correctamente
# ✅ 2020-09 descargado correctamente
# ✅ 2020-10 descargado correctamente
# ✅ 2020-11 descargado correctamente
# ✅ 2020-12 descargado correctamente
# ✅ 2021-01 descargado correctamente
# ✅ 2021-02 descargado correctamente
# ✅ 2021-03 descargado correctamente
# ✅ 2021-04 descargado correctamente
# ✅ 2021-05 descargado correctamente
# ✅ 2021-06 descargado correctamente
# ✅ 2021-07 descargado correctamente
# ✅ 2021-08 descargado correctamente
# ✅ 2021-09 descargado correctamente
# ✅ 2021-10 descargado correctamente
# ✅ 2021-11 descargado correctamente
# ✅ 2021-12 descargado correctamente
# ✅ 2022-01 descargado correctamente
# ✅ 2022-02 descargado correctamente
# ✅ 2022-03 descargado correctamente
# ✅ 2022-04 descargado correctamente
# ✅ 2022-05 descargado correctamente
# ✅ 2022-06 descargado correctamente
# ✅ 2022-07 descargado correctamente
# ✅ 2022-08 descargado correctamente
# ✅ 2022-09 descargado correctamente
# ✅ 2022-10 descargado correctamente
# ✅ 2022-11 descargado correctamente
# ✅ 2022-12 descargado correctamente

# %%
import pandas as pd
df = pd.DataFrame(diccionario)
print(df.shape)
print(df.head())
# Out:
# (3685, 5)
#      tipo_energia tipo_generacion                          fecha        valor  \
# 0      Hidráulica       Renovable  2011-01-01T00:00:00.000+01:00  5119512.380
# 1         Nuclear    No-Renovable  2011-01-01T00:00:00.000+01:00  4706500.878
# 2          Carbón    No-Renovable  2011-01-01T00:00:00.000+01:00  2303087.707
# 3      Fuel + Gas    No-Renovable  2011-01-01T00:00:00.000+01:00     -751.170
# 4  Motores diésel    No-Renovable  2011-01-01T00:00:00.000+01:00   303538.093
#
#     año
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
import requests
import pandas as pd
from time import sleep

# Diccionario de comunidades
cod_comunidades = {
    "Andalucía": 8744,
    "Aragón": 8745,
    "Asturias": 8746,
    "Baleares": 8747,
    "Canarias": 8748,
    "Cantabria": 8749,
    "Castilla-La Mancha": 8750,
    "Castilla y León": 8751,
    "Cataluña": 8752,
    "Comunidad Valenciana": 8753,
    "Extremadura": 8754,
    "Galicia": 8755,
    "Madrid": 8756,
    "Murcia": 8757,
    "Navarra": 8758,
    "País Vasco": 8759,
    "La Rioja": 8760
}

# Estructura del diccionario de resultados
diccionario_ccaa = {
    "tipo_energia": [],
    "tipo_generacion": [],
    "fecha": [],
    "valor": [],
    "ccaa": []
}

url_base = "https://apidatos.ree.es/es/datos/generacion/estructura-generacion"

# 🔁 Bucle por comunidad
for nombre, codigo in cod_comunidades.items():
    print(f"📍 Descargando datos de {nombre}...")

    params = {
        "start_date": "2022-01-01T00:00:00+01:00",
        "end_date": "2022-12-31T23:59:59+01:00",
        "time_trunc": "month",
        "geo_trunc": "ccaa",
        "geo_ids": codigo
    }

    response = requests.get(url_base, params=params)

    if response.status_code == 200:
        data = response.json()

        if "included" in data:
            for elemento in data["included"]:
                tipo_energia = elemento["attributes"]["title"]
                tipo_generacion = elemento["attributes"].get("type", "Desconocido")

                for valor in elemento["attributes"]["values"]:
                    diccionario_ccaa["tipo_energia"].append(tipo_energia)
                    diccionario_ccaa["tipo_generacion"].append(tipo_generacion)
                    diccionario_ccaa["valor"].append(valor["value"])
                    diccionario_ccaa["fecha"].append(valor["datetime"])
                    diccionario_ccaa["ccaa"].append(nombre)
        else:
            print(f"⚠️ Sin datos para {nombre}")
    else:
        print(f"❌ Error {response.status_code} en {nombre}")

    sleep(0.5)  # evitar sobrecargar la API

# Convertimos el diccionario en DataFrame
df_ccaa = pd.DataFrame(diccionario_ccaa)
print(f"\n✅ Datos descargados: {df_ccaa.shape[0]} filas")
print(df_ccaa.head())
# Out:
# 📍 Descargando datos de Andalucía...
# ❌ Error 500 en Andalucía
# 📍 Descargando datos de Aragón...
# ❌ Error 500 en Aragón
# 📍 Descargando datos de Asturias...
# ❌ Error 500 en Asturias
# 📍 Descargando datos de Baleares...
# ❌ Error 500 en Baleares
# 📍 Descargando datos de Canarias...
# ❌ Error 500 en Canarias
# 📍 Descargando datos de Cantabria...
# ❌ Error 500 en Cantabria
# 📍 Descargando datos de Castilla-La Mancha...
# ❌ Error 500 en Castilla-La Mancha
# 📍 Descargando datos de Castilla y León...
# ❌ Error 500 en Castilla y León
# 📍 Descargando datos de Cataluña...
# ❌ Error 500 en Cataluña
# 📍 Descargando datos de Comunidad Valenciana...
# ❌ Error 500 en Comunidad Valenciana
# 📍 Descargando datos de Extremadura...
# ❌ Error 500 en Extremadura
# 📍 Descargando datos de Galicia...
# ❌ Error 500 en Galicia
# 📍 Descargando datos de Madrid...
# ❌ Error 500 en Madrid
# 📍 Descargando datos de Murcia...
# ❌ Error 500 en Murcia
# 📍 Descargando datos de Navarra...
# ❌ Error 500 en Navarra
# 📍 Descargando datos de País Vasco...
# ❌ Error 500 en País Vasco
# 📍 Descargando datos de La Rioja...
# ❌ Error 500 en La Rioja
#
# ✅ Datos descargados: 0 filas
# Empty DataFrame
# Columns: [tipo_energia, tipo_generacion, fecha, valor, ccaa]
# Index: []
